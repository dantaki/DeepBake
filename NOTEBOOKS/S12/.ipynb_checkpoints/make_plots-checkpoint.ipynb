# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from glob import glob
import matplotlib as mpl
import numpy as np

# %%
# load the predictions
def load_deepbake_pred():
    preds = glob("deepbake_s12*predictions.tsv")
    df = pd.concat([pd.read_csv(f,sep='\t') for f in preds],ignore_index=True)
    df.sort_values(['episode','finalist'],inplace=True)
    return df

# %%
df = load_deepbake_pred()
df.tail(12)
# Out:
#     season      baker  episode  tech_mean  tech  mean_star  star  mean_good  \
# 84      12      Chigs        9   0.777778   1.0   0.777778   0.0   0.777778
# 24      12     Amanda       10   0.717949   0.0   0.000000   0.0   0.000000
# 28      12     George       10   0.890000   0.0   0.000000   0.0   0.388889
# 32      12     Maggie       10   0.206349   0.0   0.000000   0.0   0.388889
# 31      12     Lizzie       10   0.500000   0.0   0.000000   0.0   0.388889
# 27      12      Freya       10   0.108696   0.0   0.000000   0.0   0.583333
# 33      12    Rochica       10   0.392157   0.0   0.000000   0.0   0.000000
# 34      12        Tom       10   0.000000   0.0   0.000000   0.0   0.000000
# 30      12     Jürgen       10   0.289855   0.0   1.000000   0.0   0.909091
# 26      12  Crystelle       10   1.000000   0.8   0.833333   0.0   0.777778
# 29      12   Giuseppe       10   0.600000   1.0   0.833333   0.0   1.000000
# 25      12      Chigs       10   0.814815   0.9   0.833333   0.0   0.777778
#
#     good  mean_bad  bad  preds  bottom  finalist   top3  fifthseventh  \
# 84   1.0  0.000000  0.0      0    0.23     77.48  85.30          0.18
# 24   0.0  1.000000  0.0      2    0.01      0.06   3.55          0.01
# 28   0.0  1.000000  0.0      2    0.01      0.16  16.67          0.01
# 32   0.0  0.800000  0.0      2    0.07      0.37  15.87          0.08
# 31   0.0  0.666667  0.0      2    0.10      0.67  23.89          0.11
# 27   0.0  0.666667  0.0      2    0.17      0.77  27.36          0.18
# 33   0.0  0.277778  0.0      2    0.48      1.44  11.65          0.53
# 34   0.0  0.277778  0.0      2    0.91      1.67  11.00          1.02
# 30   0.0  0.277778  0.0      2    0.21      4.34  42.27          0.22
# 26   0.0  0.277778  0.0      0    0.17     68.90  80.94          0.19
# 29   0.0  0.277778  0.0      0    0.20     71.09  81.53          0.23
# 25   0.0  0.000000  0.0      0    0.26     73.65  81.41          0.30
#
#     thirdforth
# 84       14.28
# 24       96.44
# 28       83.30
# 32       83.98
# 31       75.90
# 27       72.28
# 33       87.35
# 34       87.08
# 30       57.30
# 26       18.71
# 29       18.04
# 25       18.03

# %%
eliminated = [
    'Tom',
    'Jairzinho',
    'Rochica',
    'Maggie',
    'Freya',
    'Amanda',
    'George',
    'Lizzie',
    'Jürgen'
]

# %%
def plot_deepbake_probs(df,prob,eliminated,title,ymax=100):
    sns.set_style('whitegrid')
    sns.set_context('talk')
    
    f, ax = plt.subplots(1,1,figsize=(8,5))

    sns.pointplot(
        x='episode',
        y=prob,
        hue='baker',
        data=df[~df['baker'].isin(eliminated)].sort_values(['episode',prob],ascending=False),
        palette='Set2',
        ax=ax
    )
    ax.set(
        xlabel='Week',
        ylabel=f'Probability [%]',
        title=f'{title}',
        yticks=[x for x in range(0,ymax+10,10)]
        
    )
    
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    
    png = f'deepbake_{prob}_week{max(df["episode"])}.png'
    f.tight_layout()
    f.savefig(png,dpi=350,bbox_inches='tight')

# %%
plot_deepbake_probs(df,'finalist',eliminated,'GBBO Winner',90)

# %%
plot_deepbake_probs(df,'top3',eliminated,'GBBO Finalist',90)

# %%
def color_fader(c1,c2,mix=0): 
    #fade (linear interpolate) from color c1 (at mix=0) to c2 (mix=1)
    c1=np.array(mpl.colors.to_rgb(c1))
    c2=np.array(mpl.colors.to_rgb(c2))
    return mpl.colors.to_hex((1-mix)*c1 + mix*c2)

# %%
episode = 10

df = load_deepbake_pred()

rename_cols = {
    'baker' : 'Baker',
    'finalist' : 'GBBO Winner',
    'top3' : 'GBBO Finalist',
    #'thirdforth' : '3rd-4th Place',
}

keep_cols = ['baker','episode','finalist','top3']#, 'thirdforth']

df = df[keep_cols].rename(columns=rename_cols)
df = df[(df['episode']==episode) & (~df['Baker'].isin(eliminated))].drop(columns=['episode'])
c1, c2 = '#1cf1b8','#fbfffe'

pal = [color_fader(c2,c1, (i)/7) for i in range(7)]
#[color_fader(c1,c2,(i+1)/len(df)) for i in range(len(df))]
pal = mpl.colors.ListedColormap(pal)

df = df.sort_values(['GBBO Winner','GBBO Finalist'],ascending= False)
df = df.round(decimals=1)
df_styled = df.style\
  .background_gradient(cmap=pal, vmin=42, vmax=95)\
  .hide_index()\
  .format('{:.1f}',subset=['GBBO Winner','GBBO Finalist',])#'3rd-4th Place'])
# Out:
# /var/folders/zp/f54zy6rd5j334fnd0lds81780000gp/T/ipykernel_28458/1098642849.py:24: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   df_styled = df.style\

# %%
[color_fader(c2,c1, (i)/10) for i in range(10)]
# Out:
# ['#fbfffe',
#  '#e5fef7',
#  '#cefcf0',
#  '#b8fbe9',
#  '#a2f9e2',
#  '#8bf8db',
#  '#75f7d4',
#  '#5ff5cd',
#  '#49f4c6',
#  '#32f2bf']

# %%
df_styled
# Out:
# <style type="text/css">
# #T_c9553_row0_col1 {
#   background-color: #7cf7d6;
#   color: #000000;
# }
# #T_c9553_row0_col2, #T_c9553_row1_col2, #T_c9553_row2_col2 {
#   background-color: #5cf5cc;
#   color: #000000;
# }
# #T_c9553_row1_col1, #T_c9553_row2_col1 {
#   background-color: #9bf9e0;
#   color: #000000;
# }
# </style>
# <table id="T_c9553">
#   <thead>
#     <tr>
#       <th id="T_c9553_level0_col0" class="col_heading level0 col0" >Baker</th>
#       <th id="T_c9553_level0_col1" class="col_heading level0 col1" >GBBO Winner</th>
#       <th id="T_c9553_level0_col2" class="col_heading level0 col2" >GBBO Finalist</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c9553_row0_col0" class="data row0 col0" >Chigs</td>
#       <td id="T_c9553_row0_col1" class="data row0 col1" >73.6</td>
#       <td id="T_c9553_row0_col2" class="data row0 col2" >81.4</td>
#     </tr>
#     <tr>
#       <td id="T_c9553_row1_col0" class="data row1 col0" >Giuseppe</td>
#       <td id="T_c9553_row1_col1" class="data row1 col1" >71.1</td>
#       <td id="T_c9553_row1_col2" class="data row1 col2" >81.5</td>
#     </tr>
#     <tr>
#       <td id="T_c9553_row2_col0" class="data row2 col0" >Crystelle</td>
#       <td id="T_c9553_row2_col1" class="data row2 col1" >68.9</td>
#       <td id="T_c9553_row2_col2" class="data row2 col2" >80.9</td>
#     </tr>
#   </tbody>
# </table>

# %%
with open('deepbake_probs.html', 'w') as f:
    f.write(df_styled.render())
# Out:
# /var/folders/zp/f54zy6rd5j334fnd0lds81780000gp/T/ipykernel_28458/259224156.py:2: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   f.write(df_styled.render())

# %%
pal

# %%
# Out:
# ['#e8fef8',
#  '#ddfdf4',
#  '#d2fdf1',
#  '#c7fcee',
#  '#bcfbea',
#  '#b0fbe6',
#  '#a5fae3',
#  '#9af9e0',
#  '#8ff8dc',
#  '#84f8d9']
