# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from glob import glob
import matplotlib as mpl
import numpy as np

# %%
# load the predictions
def load_deepbake_pred():
    preds = glob("deepbake_s13*predictions.tsv")
    df = pd.concat([pd.read_csv(f,sep='\t') for f in preds],ignore_index=True)
    df.sort_values(['episode','finalist'],inplace=True)
    return df

# %%
df = load_deepbake_pred()
df.tail(12)
# Out:
#     season    baker  episode  tech_mean      tech  mean_star  star  mean_good  \
# 30      13   Maisam        3   0.222222  0.000000   0.000000   0.0   0.000000
# 32      13     Rebs        3   0.222222  0.000000   0.000000   0.0   0.000000
# 35      13     Will        3   0.000000  0.000000   0.000000   0.0   0.000000
# 25      13   Carole        3   1.000000  1.000000   0.000000   0.0   0.000000
# 29      13    Kevin        3   0.908602  0.909091   0.000000   0.0   0.000000
# 26      13     Dawn        3   0.818182  0.818182   0.000000   0.0   0.000000
# 24      13    Abdul        3   0.611111  0.000000   0.000000   0.0   0.000000
# 33      13   Sandro        3   0.000000  0.636364   0.000000   0.0   0.888889
# 34      13  Syabira        3   0.464158  0.727273   0.000000   0.0   1.000000
# 27      13    James        3   0.611111  0.545455   0.000000   0.0   0.666667
# 28      13   Janusz        3   0.363969  0.363636   1.000000   1.0   0.888889
# 31      13     Maxy        3   0.611111  0.454545   0.908602   0.0   0.666667
#
#     good  mean_bad  bad  preds  bottom  finalist   top3  fifthseventh  \
# 30   0.0  1.000000  0.0      2    0.05      0.82   3.27          0.06
# 32   0.0  1.000000  0.0      2    0.05      0.82   3.27          0.06
# 35   0.0  0.611111  0.0      2    0.56      3.34  10.47          0.60
# 25   0.0  1.000000  1.0      2    0.01      3.38  15.42          0.01
# 29   0.0  0.611111  1.0      2    0.03      6.03  21.94          0.02
# 26   0.0  0.611111  1.0      2    0.04      6.23  23.66          0.03
# 24   0.0  0.000000  0.0      2    1.54     15.77  33.43          1.48
# 33   1.0  0.000000  0.0      2    0.24     21.05  43.06          0.20
# 34   1.0  0.000000  0.0      2    0.09     22.30  41.40          0.07
# 27   0.0  0.000000  0.0      2    0.40     24.15  45.51          0.35
# 28   1.0  0.000000  0.0      0    0.14     37.52  71.49          0.12
# 31   0.0  0.000000  0.0      0    0.41     41.57  67.11          0.37
#
#     thirdforth
# 30       96.63
# 32       96.63
# 35       88.37
# 25       84.56
# 29       78.01
# 26       76.27
# 24       63.54
# 33       56.50
# 34       58.44
# 27       53.74
# 28       28.25
# 31       32.12

# %%
eliminated = ['Will',
              'Maisam',
]

# %%
def plot_deepbake_probs(df,prob,eliminated,title,ymax=100):
    sns.set_style('whitegrid')
    sns.set_context('talk')
    
    f, ax = plt.subplots(1,1,figsize=(8,5))

    sns.pointplot(
        x='episode',
        y=prob,
        hue='baker',
        data=df[~df['baker'].isin(eliminated)].sort_values(['episode',prob],ascending=False),
        palette='Set2',
        ax=ax
    )
    ax.set(
        xlabel='Week',
        ylabel=f'Probability [%]',
        title=f'{title}',
        yticks=[x for x in range(0,ymax+10,10)]
        
    )
    
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    
    png = f'deepbake_{prob}_week{max(df["episode"])}.png'
    f.tight_layout()
    f.savefig(png,dpi=350,bbox_inches='tight')

# %%
plot_deepbake_probs(df,'finalist',eliminated,'GBBO Winner',90)

# %%
plot_deepbake_probs(df,'top3',eliminated,'GBBO Finalist',90)

# %%
def color_fader(c1,c2,mix=0): 
    #fade (linear interpolate) from color c1 (at mix=0) to c2 (mix=1)
    c1=np.array(mpl.colors.to_rgb(c1))
    c2=np.array(mpl.colors.to_rgb(c2))
    return mpl.colors.to_hex((1-mix)*c1 + mix*c2)

# %%
episode = 9

df = load_deepbake_pred()

rename_cols = {
    'baker' : 'Baker',
    'finalist' : 'GBBO Winner',
    'top3' : 'GBBO Finalist',
    #'thirdforth' : '3rd-4th Place',
}

keep_cols = ['baker','episode','finalist','top3']#, 'thirdforth']

df = df[keep_cols].rename(columns=rename_cols)
df = df[(df['episode']==episode) & (~df['Baker'].isin(eliminated))].drop(columns=['episode'])
c1, c2 = '#1cf1b8','#fbfffe'

pal = [color_fader(c2,c1, (i)/7) for i in range(7)]
#[color_fader(c1,c2,(i+1)/len(df)) for i in range(len(df))]
pal = mpl.colors.ListedColormap(pal)

df = df.sort_values(['GBBO Winner','GBBO Finalist'],ascending= False)
df = df.round(decimals=1)
df_styled = df.style\
  .background_gradient(cmap=pal, vmin=42, vmax=95)\
  .hide_index()\
  .format('{:.1f}',subset=['GBBO Winner','GBBO Finalist',])#'3rd-4th Place'])

# %%
[color_fader(c2,c1, (i)/10) for i in range(10)]
# Out:
# ['#fbfffe',
#  '#e5fef7',
#  '#cefcf0',
#  '#b8fbe9',
#  '#a2f9e2',
#  '#8bf8db',
#  '#75f7d4',
#  '#5ff5cd',
#  '#49f4c6',
#  '#32f2bf']

# %%
df_styled
# Out:
# <style  type="text/css" >
# #T_2131f_row0_col1{
#             background-color:  #7cf7d6;
#             color:  #000000;
#         }#T_2131f_row0_col2{
#             background-color:  #5cf5cc;
#             color:  #000000;
#         }#T_2131f_row1_col1{
#             background-color:  #bbfbea;
#             color:  #000000;
#         }#T_2131f_row1_col2{
#             background-color:  #9bf9e0;
#             color:  #000000;
#         }#T_2131f_row2_col1,#T_2131f_row3_col1{
#             background-color:  #fbfffe;
#             color:  #000000;
#         }#T_2131f_row2_col2,#T_2131f_row3_col2{
#             background-color:  #3cf3c2;
#             color:  #000000;
#         }</style><table id="T_2131f_" ><thead>    <tr>        <th class="col_heading level0 col0" >Baker</th>        <th class="col_heading level0 col1" >GBBO Winner</th>        <th class="col_heading level0 col2" >GBBO Finalist</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_2131f_row0_col0" class="data row0 col0" >Chigs</td>
#                         <td id="T_2131f_row0_col1" class="data row0 col1" >77.5</td>
#                         <td id="T_2131f_row0_col2" class="data row0 col2" >85.3</td>
#             </tr>
#             <tr>
#                                 <td id="T_2131f_row1_col0" class="data row1 col0" >Crystelle</td>
#                         <td id="T_2131f_row1_col1" class="data row1 col1" >61.0</td>
#                         <td id="T_2131f_row1_col2" class="data row1 col2" >65.9</td>
#             </tr>
#             <tr>
#                                 <td id="T_2131f_row2_col0" class="data row2 col0" >Jürgen</td>
#                         <td id="T_2131f_row2_col1" class="data row2 col1" >45.3</td>
#                         <td id="T_2131f_row2_col2" class="data row2 col2" >93.4</td>
#             </tr>
#             <tr>
#                                 <td id="T_2131f_row3_col0" class="data row3 col0" >Giuseppe</td>
#                         <td id="T_2131f_row3_col1" class="data row3 col1" >42.5</td>
#                         <td id="T_2131f_row3_col2" class="data row3 col2" >93.7</td>
#             </tr>
#     </tbody></table>

# %%
with open('deepbake_probs.html', 'w') as f:
    f.write(df_styled.render())

# %%
pal

# %%
# Out:
# ['#e8fef8',
#  '#ddfdf4',
#  '#d2fdf1',
#  '#c7fcee',
#  '#bcfbea',
#  '#b0fbe6',
#  '#a5fae3',
#  '#9af9e0',
#  '#8ff8dc',
#  '#84f8d9']
